-- %%
CREATE CATALOG IF NOT EXISTS customer_orders_task;

USE CATALOG customer_orders_task;

CREATE SCHEMA IF NOT EXISTS customer_orders_task.bronze;
CREATE SCHEMA IF NOT EXISTS customer_orders_task.silver;
CREATE SCHEMA IF NOT EXISTS customer_orders_task.gold;

SHOW DATABASES FROM customer_orders_task;


CREATE SCHEMA IF NOT EXISTS customer_orders_task.source_data;



DROP MATERIALIZED VIEW IF EXISTS gold.customer_summary;
DROP MATERIALIZED VIEW IF EXISTS gold.fact_orders;
